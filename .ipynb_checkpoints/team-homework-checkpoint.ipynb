# %%
#一个确认数据类型是不是统一的代码，但是一次只能确定某一列
lenth=len(df.columns)
for i in range(lenth):
    column_types = df.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')

# %% [markdown]
# # 第一问

# %%
import pandas as pd

# %%
df1 = pd.read_csv('credits.csv')  
df1.fillna('NaN', inplace=True)

#一个确认数据类型是不是统一的代码
lenth=len(df1.columns)
for i in range(lenth):
    column_types = df1.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)
df1  
#以上是第一个表格的载入和类型转化
# Out:
# [<class 'str'>]
# [<class 'str'>]
# [<class 'int'>]
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# ...

# %%
df2 = pd.read_csv('keywords.csv')  
df2.fillna('NaN', inplace=True)

#一个确认数据类型是不是统一的代码
lenth=len(df2.columns)
for i in range(lenth):
    column_types = df2.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)

df2
#以上是第二个表格的载入和类型转化
# Out:
# [<class 'int'>]
# [<class 'str'>]
#            id                                           keywords
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
# [46419 rows x 2 columns]

# %%
df3 = pd.read_csv('links.csv')  
df3.fillna('NaN', inplace=True)
df3['tmdbId'] = pd.to_numeric(df3['tmdbId'], errors='coerce')


#一个确认数据类型是不是统一的代码
lenth=len(df3.columns)
for i in range(lenth):
    column_types = df3.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)


df3
#以上是第三个表格的载入和类型转化
# Out:
# [<class 'int'>]
# [<class 'int'>]
# [<class 'float'>]
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
df4 = pd.read_csv('links_small.csv')  
df4.fillna('NaN', inplace=True)
df4['tmdbId'] = pd.to_numeric(df4['tmdbId'], errors='coerce')

#一个确认数据类型是不是统一的代码
lenth=len(df4.columns)
for i in range(lenth):
    column_types = df4.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)
        
df4
#以上是第四个表格的载入和类型转化
# Out:
# [<class 'int'>]
# [<class 'int'>]
# [<class 'float'>]
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %%
df5 = pd.read_csv('movies_metadata.csv', dtype={10: str})
df5.fillna('NaN', inplace=True)

df5.iloc[:, 10]=pd.to_numeric(df5.iloc[:, 10],errors='coerce')
df5['budget'] = pd.to_numeric(df5['budget'], errors='coerce')
df5['id'] = pd.to_numeric(df5['id'], errors='coerce')
df5['revenue'] = pd.to_numeric(df5['revenue'], errors='coerce')
df5.iloc[:, 16]=pd.to_numeric(df5.iloc[:, 16],errors='coerce')
df5.iloc[:, 21] = df5.iloc[:, 21].astype(bool)
df5.iloc[:, 22]=pd.to_numeric(df5.iloc[:, 22],errors='coerce')
df5.iloc[:, 23]=pd.to_numeric(df5.iloc[:, 23],errors='coerce')
#这里这么多是NAN被统一识别了str，在手动转换

#一个确认数据类型是不是统一的代码
lenth=len(df5.columns)
for i in range(lenth):
    column_types = df5.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)

df5
#以上是第五个表格的载入和类型转化
# Out:
# [<class 'str'>]
# [<class 'str'>]
# [<class 'float'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'float'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'float'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'float'>]
# [<class 'float'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'str'>]
# [<class 'bool'>]
# [<class 'float'>]
# [<class 'float'>]
#        adult                              belongs_to_collection      budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1      False                                                NaN  65000000.0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3      False                                                NaN  16000000.0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...      ...                                                ...         ...
# ...

# %%
df6 = pd.read_csv('ratings.csv')
df6.fillna('NaN', inplace=True)


#一个确认数据类型是不是统一的代码
lenth=len(df6.columns)
for i in range(lenth):
    column_types = df6.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)


df6
#以上是第六个表格的载入和类型转化
# Out:
# [<class 'int'>]
# [<class 'int'>]
# [<class 'float'>]
# [<class 'int'>]
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
df7 = pd.read_csv('ratings_small.csv')
df7.fillna('NaN', inplace=True)


#一个确认数据类型是不是统一的代码
lenth=len(df7.columns)
for i in range(lenth):
    column_types = df7.iloc[:, i].apply(type)
    unique_types = column_types.unique()
    if len(unique_types) != 1:
        print('第', i+1,'列数据存在不同类别')
    print(unique_types)


df7
#以上是第七个表格的载入和类型转化
# Out:
# [<class 'int'>]
# [<class 'int'>]
# [<class 'float'>]
# [<class 'int'>]
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %% [markdown]
# # 第二问

# %%
df_merged = pd.merge(df1, df2, on='id')
df_merged = pd.merge(df_merged, df5, on='id')  #第五列是浮点数，暂时看不出来问题，如果有问题可以把1,2里面的整数换掉
df_merged = pd.merge(df_merged, df3, left_on='id', right_on='tmdbId') #3和4相似度很高啊，留一个
df_merged = pd.merge(df_merged, df7, on='movieId') #?这俩会不会太多了
#会，但后面要用所以找了个小的


df_merged = df_merged.loc[:,~df_merged.columns.duplicated()]
df_merged['rating']
# Out:
# 0         3.0
# 1         4.0
# 2         5.0
# 3         2.0
# 4         3.0
#          ...
# 100117    1.5
# 100118    5.0
# 100119    5.0
# 100120    3.0
# 100121    5.0
# Name: rating, Length: 100122, dtype: float64

# %%
# 生成数值列的统计信息
summary_statistics = df_merged.describe()
summary_statistics  #这个统计没意义啊0太多了。但是删除0的话很多其他有效的数据都会被删掉。一个一个手动删除来这也太多了吧
#看了后面一问，这个要改，删除重复项
# Out:
#                   id        budget    popularity       revenue       runtime  \
# count   46910.000000  4.691000e+04  46906.000000  4.690600e+04  46642.000000
# mean   109583.906544  4.160452e+06      2.895200  1.099131e+07     94.125466
# std    112714.469859  1.723756e+07      5.939436  6.362456e+07     38.380166
# min         2.000000  0.000000e+00      0.000000  0.000000e+00      0.000000
# 25%     26699.250000  0.000000e+00      0.383576  0.000000e+00     85.000000
# 50%     61474.000000  0.000000e+00      1.115900  0.000000e+00     95.000000
# 75%    159180.500000  0.000000e+00      3.614359  0.000000e+00    107.000000
# max    469172.000000  3.800000e+08    547.488298  2.787965e+09   1256.000000
#
#        vote_average    vote_count        movieId        imdbId         tmdbId
# count  46906.000000  46906.000000   46910.000000  4.691000e+04   46910.000000
# mean       5.611645    107.784569   97527.215178  1.002612e+06  109583.906544
# ...

# %%
import matplotlib.pyplot as plt

# 探索电影评分的分布
plt.figure(figsize=(10, 5))
plt.hist(df_merged['rating'].dropna(), bins=20, edgecolor='black')
plt.title('fenbu')
plt.xlabel('rating')
plt.ylabel('pin')
plt.show()

df_merged = df_merged.drop_duplicates(subset=['original_title']) #把重复的电影名字去掉了，这个数据到底是以编号为主还是名字为主啊！
filtered_data = df_merged[df_merged['revenue'] != 0]  #把0去掉了，这个数太荒谬了好家伙
# 探索电影收入的分布
plt.figure(figsize=(10, 5))
plt.hist(filtered_data['revenue'].dropna(), bins=10, edgecolor='black')
plt.title('fenbu')
plt.xlabel('revenue')
plt.ylabel('pin')
plt.show()
#le9代表数据很大

# %%
# 识别收入最高的前10部电影
df_merged = df_merged.drop_duplicates(subset=['original_title'])
top10_highest_grossing = df_merged.nlargest(10, 'revenue')[['original_title', 'revenue']]
top10_highest_grossing
# Out:
#                                      original_title       revenue
# 94146                                        Avatar  2.787965e+09
# 99442                  Star Wars: The Force Awakens  2.068224e+09
# 40283                                       Titanic  1.845034e+09
# 99304                                Jurassic World  1.513529e+09
# 99627                                     Furious 7  1.506249e+09
# 99475                       Avengers: Age of Ultron  1.405404e+09
# 96102  Harry Potter and the Deathly Hallows: Part 2  1.342000e+09
# 98297                                        Frozen  1.274219e+09
# 97750                                    Iron Man 3  1.215440e+09
# 99788                                       Minions  1.156731e+09
